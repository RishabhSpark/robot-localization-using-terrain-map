# %%
import numpy as np
import cv2

map = cv2.imread("images\map2.png", 0)
map
# Out:
# array([[112, 148, 137, ..., 134, 133, 128],
#        [139, 143, 110, ..., 130, 132, 118],
#        [137, 131, 102, ..., 129, 133, 135],
#        ...,
#        [ 71,  72,  72, ..., 123, 123, 123],
#        [ 73,  73,  73, ..., 123, 123, 123],
#        [ 74,  74,  74, ..., 123, 123, 123]], dtype=uint8)

# %%
HEIGHT, WIDTH = map.shape

print(map)
rx, ry, rtheta = (WIDTH/4, HEIGHT/4, 0)
# Out:
# [[112 148 137 ... 134 133 128]
#  [139 143 110 ... 130 132 118]
#  [137 131 102 ... 129 133 135]
#  ...
#  [ 71  72  72 ... 123 123 123]
#  [ 73  73  73 ... 123 123 123]
#  [ 74  74  74 ... 123 123 123]]

# %%
STEP = 5
TURN = np.radians(25)

def get_input():
    fwd = 0
    turn = 0
    halt = False
    k = cv2.waitKey(0)
    if k == ord('w'):
        fwd = STEP
    elif k == ord('d'):
        turn = TURN
    elif k == ord('a'):
        turn = -TURN
    else:
        halt = True
    return fwd, turn, halt

# %%
MOVE_STEP = 0.5
MOVE_TURN = np.radians(5)
def move_robot(rx, ry, rtheta, fwd, turn):
    fwd_noisy = np.random.normal(fwd, MOVE_STEP, 1)
    rx = rx + fwd_noisy*np.cos(rtheta)
    ry = ry + fwd_noisy*np.sin(rtheta)
    print("fwd noisy = ", fwd_noisy)
    
    turn_noisy = np.random.normal(turn, MOVE_TURN, 1)
    rtheta = rtheta + turn_noisy
    print("turn noisy = ", np.degrees(turn_noisy))
    
    return rx, ry, rtheta

# %%
NUM_PARTICLES = 3000

def init():
    particles = np.random.rand(NUM_PARTICLES, 3)
    particles *= np.array((WIDTH, HEIGHT, np.radians(360)) )
    return particles

# %%
def move_particles(particles, fwd, turn):
    particles[:,0] += fwd*np.cos(particles[:,2])
    particles[:,1] += fwd*np.sin(particles[:,2])
    particles[:,2] += turn
    
    particles[:,0] = np.clip(particles[:,0], 0.0, WIDTH-1)
    particles[:,1] = np.clip(particles[:,1], 0.0, HEIGHT-1)
    
    return particles

# %%
SIGMA_SENSOR = 2
def sense(x, y, noisy=False):
    SIGMA_SENSOR = 5
    x = int(x)
    y = int(y)
    if noisy:
        return map[y,x] + np.random.normal(0.0, SIGMA_SENSOR, 1)
    return map[y,x]

# %%
def compute_weights(particles, robot_sensor):    
    errors = np.zeros(NUM_PARTICLES)
    for i in range(NUM_PARTICLES):
        particle_sensor = sense(particles[i,0], particles[i,1])
        errors[i] = abs(robot_sensor - particle_sensor)
    weights = np.max(errors) - errors
    
    weights[
        (particles[:,0] == 0) |
        (particles[:,0] == WIDTH-1) |
        (particles[:,1] == 0) |
        (particles[:,1] == HEIGHT-1)
    ] = 0.0

    weights = weights ** 3
    return weights

# %%
def resample(particles, weights):
    probabilities = weights / np.sum(weights)
    new_index = np.random.choice(
        NUM_PARTICLES,
        size=NUM_PARTICLES,
        p=probabilities
    )
    particles = particles[new_index,:]
    return particles

# %%
def add_noise(particles):
    SIGMA_PARTICLE_STEP = 2 #2
    SIGMA_PARTICLE_TURN = np.pi / 24 #np.pi / 24
    noise = np.concatenate((
        np.random.normal(0, SIGMA_PARTICLE_STEP, (NUM_PARTICLES,1)),
        np.random.normal(0, SIGMA_PARTICLE_STEP, (NUM_PARTICLES,1)),
        np.random.normal(0, SIGMA_PARTICLE_TURN, (NUM_PARTICLES,1)),
        ),
        axis=1
    )
    particles += noise
    return particles

# %%
def display(map, rx, ry, particles):
    lmap = cv2.cvtColor(map, cv2.COLOR_GRAY2BGR)
    
    # Display particles
    if len(particles) > 0:
        for i in range(NUM_PARTICLES):
            cv2.circle(lmap, 
                       (int(particles[i,0]), int(particles[i,1])), 
                       1, 
                       (255,0,0), 
                       1)
        
    # Display robot
    cv2.circle(lmap, (int(rx), int(ry)), 5, (0,255,0), 10)

    # Display best guess
    if len(particles) > 0:
        px = np.mean(particles[:,0])
        py = np.mean(particles[:,1])
        cv2.circle(lmap, (int(px), int(py)), 5, (0,0,255), 5)

    cv2.imshow('map', lmap)

# %%
particles = init()
while True:
    display(map, rx, ry, particles)
    fwd, turn, halt = get_input()
    if halt:
        break
    rx, ry, rtheta = move_robot(rx, ry, rtheta, fwd, turn)
    particles = move_particles(particles, fwd, turn)
    if fwd != 0:
        robot_sensor = sense(rx, ry, noisy=True)        
        weights = compute_weights(particles, robot_sensor)
        particles = resample(particles, weights)
        particles = add_noise(particles)
    
cv2.destroyAllWindows()
# Out:
# fwd noisy =  [4.94118439]
# turn noisy =  [5.71114556]
# fwd noisy =  [5.21660275]
# turn noisy =  [3.14277275]
# fwd noisy =  [4.82323984]
# turn noisy =  [-7.53930694]
# fwd noisy =  [5.54420179]
# turn noisy =  [2.39904408]
# fwd noisy =  [4.73973527]
# turn noisy =  [-1.79463068]
# fwd noisy =  [4.41336361]
# turn noisy =  [-2.28978646]
# fwd noisy =  [4.90206233]
# turn noisy =  [-6.58668674]
# fwd noisy =  [4.53384049]
# turn noisy =  [9.02351969]
# fwd noisy =  [4.38648481]
# turn noisy =  [-0.56599383]
# fwd noisy =  [6.03679449]
# turn noisy =  [-7.70549269]
# fwd noisy =  [5.03365639]
# turn noisy =  [6.05650458]
# fwd noisy =  [5.34634158]
# turn noisy =  [5.04805235]
# fwd noisy =  [4.86773833]
# turn noisy =  [-2.51744822]
# fwd noisy =  [4.7376237]
# turn noisy =  [0.4932002]
# fwd noisy =  [5.15897732]
# turn noisy =  [0.7461778]
# fwd noisy =  [5.38073087]
# turn noisy =  [6.53171686]
# fwd noisy =  [4.46938616]
# turn noisy =  [-3.96587523]
# fwd noisy =  [4.53663084]
# turn noisy =  [-7.18220014]
# fwd noisy =  [5.49014437]
# turn noisy =  [1.70714058]
# fwd noisy =  [5.75585358]
# turn noisy =  [-5.77217786]
# fwd noisy =  [4.9265154]
# turn noisy =  [13.88143905]
# fwd noisy =  [5.54803157]
# turn noisy =  [9.4296889]
# fwd noisy =  [4.74266691]
# turn noisy =  [0.22887355]
# fwd noisy =  [4.36509889]
# turn noisy =  [0.74286069]
# fwd noisy =  [4.87930426]
# turn noisy =  [-7.2381206]
# fwd noisy =  [4.65946606]
# turn noisy =  [5.03557396]
# fwd noisy =  [4.72600711]
# turn noisy =  [2.09634647]
# fwd noisy =  [5.16753718]
# turn noisy =  [-1.40311666]
# fwd noisy =  [5.32617417]
# turn noisy =  [6.73367349]
# fwd noisy =  [5.07050558]
# turn noisy =  [1.8468021]
# fwd noisy =  [4.76083989]
# turn noisy =  [2.83509433]
# fwd noisy =  [5.31512056]
# turn noisy =  [0.2091956]
# fwd noisy =  [4.80796117]
# turn noisy =  [1.3838702]
# fwd noisy =  [4.95562164]
# turn noisy =  [-4.20471817]
# fwd noisy =  [-0.03298657]
# turn noisy =  [33.65164298]
# fwd noisy =  [-0.07411972]
# turn noisy =  [30.15743151]
# fwd noisy =  [5.10945525]
# turn noisy =  [4.25350155]
# fwd noisy =  [4.73389736]
# turn noisy =  [-9.54000663]
# fwd noisy =  [4.39519031]
# turn noisy =  [5.97053693]
# fwd noisy =  [4.4912081]
# turn noisy =  [3.70527036]
# fwd noisy =  [4.86927488]
# turn noisy =  [3.01225966]
# fwd noisy =  [5.85103221]
# turn noisy =  [-1.39858563]
# fwd noisy =  [4.90842476]
# turn noisy =  [-4.51493198]
# fwd noisy =  [4.67643703]
# turn noisy =  [-3.71506886]
# fwd noisy =  [4.59055906]
# turn noisy =  [5.15778557]
# fwd noisy =  [5.26869258]
# turn noisy =  [0.98329566]
# fwd noisy =  [5.58274163]
# turn noisy =  [0.22804562]
# fwd noisy =  [4.94774243]
# turn noisy =  [-3.55755775]
# fwd noisy =  [4.70371966]
# turn noisy =  [1.08412863]
# fwd noisy =  [4.7533435]
# turn noisy =  [-16.70306118]
# fwd noisy =  [5.32134154]
# turn noisy =  [-0.63448291]
# fwd noisy =  [4.43428865]
# turn noisy =  [-0.65969231]
# fwd noisy =  [6.04429309]
# turn noisy =  [-2.50602866]
# fwd noisy =  [4.7900527]
# turn noisy =  [-6.90563041]
# fwd noisy =  [-0.06034567]
# turn noisy =  [30.32593013]
# fwd noisy =  [0.09093158]
# turn noisy =  [22.66013684]
# fwd noisy =  [5.0907365]
# turn noisy =  [11.32642689]
# fwd noisy =  [4.81426495]
# turn noisy =  [-0.92747067]
# fwd noisy =  [4.68534477]
# turn noisy =  [8.67989243]
# fwd noisy =  [5.33890051]
# turn noisy =  [-8.22939365]
# fwd noisy =  [4.92769833]
# turn noisy =  [6.80492277]
# fwd noisy =  [3.85414705]
# turn noisy =  [-3.10195524]
# fwd noisy =  [5.02414628]
# turn noisy =  [-3.22593717]
# fwd noisy =  [4.94463056]
# turn noisy =  [-1.91112509]
# fwd noisy =  [4.256124]
# turn noisy =  [-2.55036068]
# fwd noisy =  [4.82589608]
# turn noisy =  [5.07280603]
# fwd noisy =  [4.72245937]
# turn noisy =  [0.48530486]
# fwd noisy =  [5.95264012]
# turn noisy =  [1.58747274]
# fwd noisy =  [5.1695452]
# turn noisy =  [2.74832951]
# fwd noisy =  [5.11534903]
# turn noisy =  [-5.18058572]
# fwd noisy =  [4.85514501]
# turn noisy =  [8.98033144]
# fwd noisy =  [4.12127687]
# turn noisy =  [0.01527066]
# fwd noisy =  [5.37070144]
# turn noisy =  [-2.04750024]
# fwd noisy =  [5.0072808]
# turn noisy =  [0.06161496]
# fwd noisy =  [5.20085508]
# turn noisy =  [1.28567605]
# fwd noisy =  [4.81060289]
# turn noisy =  [-1.53568476]
# fwd noisy =  [4.80544477]
# turn noisy =  [2.12741492]
# fwd noisy =  [5.59426788]
# turn noisy =  [1.83570849]
# fwd noisy =  [5.29914379]
# turn noisy =  [7.65162389]
# fwd noisy =  [4.94056403]
# turn noisy =  [-5.02384502]
# fwd noisy =  [4.91508466]
# turn noisy =  [0.43496192]
# fwd noisy =  [6.3087923]
# turn noisy =  [-4.67720891]
# fwd noisy =  [4.42642762]
# turn noisy =  [-3.51531218]
# fwd noisy =  [4.97605564]
# turn noisy =  [-1.18988865]
# fwd noisy =  [5.01804667]
# turn noisy =  [-7.00671773]
# fwd noisy =  [5.41801144]
# turn noisy =  [-0.6736469]
# fwd noisy =  [4.94363612]
# turn noisy =  [2.31681939]
# fwd noisy =  [4.81460212]
# turn noisy =  [2.71632984]
# fwd noisy =  [5.04759484]
# turn noisy =  [-4.63635702]
# fwd noisy =  [5.43872379]
# turn noisy =  [-3.28139736]
# fwd noisy =  [4.09335348]
# turn noisy =  [-0.1447903]
# fwd noisy =  [4.2320694]
# turn noisy =  [11.19206645]
# fwd noisy =  [3.96380007]
# turn noisy =  [-2.13927103]
# fwd noisy =  [4.9645227]
# turn noisy =  [0.13919653]
# fwd noisy =  [5.14925696]
# turn noisy =  [5.30658911]
# fwd noisy =  [4.94284523]
# turn noisy =  [9.54600198]
# fwd noisy =  [5.2776243]
# turn noisy =  [0.30732839]
# fwd noisy =  [4.61286141]
# turn noisy =  [-10.41689689]
# fwd noisy =  [4.85208277]
# turn noisy =  [-7.27437989]
# fwd noisy =  [5.26254139]
# turn noisy =  [2.57637554]
# fwd noisy =  [4.94820505]
# turn noisy =  [5.46601368]
# fwd noisy =  [5.42987716]
# turn noisy =  [3.19476664]
# fwd noisy =  [4.39826405]
# turn noisy =  [2.26436162]
# fwd noisy =  [4.66652553]
# turn noisy =  [-8.56826366]
# fwd noisy =  [5.17741801]
# turn noisy =  [8.59384648]
# fwd noisy =  [5.25370403]
# turn noisy =  [-3.64900487]
# fwd noisy =  [3.93207748]
# turn noisy =  [1.74838852]
# fwd noisy =  [5.43005641]
# turn noisy =  [-1.59147383]
# fwd noisy =  [5.43139383]
# turn noisy =  [-2.55483391]
# fwd noisy =  [4.89402509]
# turn noisy =  [2.03489914]
# fwd noisy =  [5.14983262]
# turn noisy =  [-1.1145469]
# fwd noisy =  [5.23106659]
# turn noisy =  [2.89442715]
# fwd noisy =  [4.95707764]
# turn noisy =  [4.68784112]
# fwd noisy =  [5.59035024]
# turn noisy =  [-1.91258338]
# fwd noisy =  [6.05480761]
# turn noisy =  [7.75266745]
# fwd noisy =  [4.7457189]
# turn noisy =  [-4.10329709]
# fwd noisy =  [5.06035555]
# turn noisy =  [-5.50802559]
# fwd noisy =  [4.75270023]
# turn noisy =  [4.75348153]
# fwd noisy =  [5.578337]
# turn noisy =  [3.4843641]
# fwd noisy =  [4.86508564]
# turn noisy =  [-1.0187458]
# fwd noisy =  [4.90449516]
# turn noisy =  [0.25401511]
# fwd noisy =  [5.31230435]
# turn noisy =  [-12.99512694]
# fwd noisy =  [5.16242894]
# turn noisy =  [8.4696712]
# fwd noisy =  [0.13701322]
# turn noisy =  [36.33055758]
# fwd noisy =  [-0.08772888]
# turn noisy =  [26.29712261]
# fwd noisy =  [0.82504981]
# turn noisy =  [28.57829867]
# fwd noisy =  [4.85483574]
# turn noisy =  [1.33710157]
# fwd noisy =  [4.2668257]
# turn noisy =  [4.87889992]
# fwd noisy =  [4.63192211]
# turn noisy =  [-16.34895912]
# fwd noisy =  [5.15275033]
# turn noisy =  [-5.69196643]
# fwd noisy =  [0.79445386]
# turn noisy =  [18.97772328]
# fwd noisy =  [-0.55728212]
# turn noisy =  [24.2155639]
# fwd noisy =  [-0.31720162]
# turn noisy =  [29.36915211]
# fwd noisy =  [5.42338465]
# turn noisy =  [4.42306991]
# fwd noisy =  [4.93080305]
# turn noisy =  [9.403798]
# fwd noisy =  [5.15060139]
# turn noisy =  [-4.81977164]
# fwd noisy =  [4.39028338]
# turn noisy =  [-0.83246143]
# fwd noisy =  [4.72007037]
# turn noisy =  [-4.23236853]
# fwd noisy =  [4.74376282]
# turn noisy =  [0.13454557]
# fwd noisy =  [4.58146132]
# turn noisy =  [4.07246643]
# fwd noisy =  [4.54536319]
# turn noisy =  [-1.37530058]
# fwd noisy =  [4.70479754]
# turn noisy =  [1.16984226]
# fwd noisy =  [4.65690914]
# turn noisy =  [-4.4206215]
# fwd noisy =  [4.74119203]
# turn noisy =  [-1.82927726]
# fwd noisy =  [4.83939482]
# turn noisy =  [4.35327867]
# fwd noisy =  [4.39301467]
# turn noisy =  [-0.34373171]
# fwd noisy =  [5.31653731]
# turn noisy =  [-5.13510485]
# fwd noisy =  [5.52329264]
# turn noisy =  [7.46967346]
# fwd noisy =  [4.81465759]
# turn noisy =  [2.59247784]
# fwd noisy =  [5.26501166]
# turn noisy =  [5.43507019]
# fwd noisy =  [5.14682538]
# turn noisy =  [1.6459293]
# fwd noisy =  [5.01338008]
# turn noisy =  [2.83542013]
# fwd noisy =  [5.41832103]
# turn noisy =  [-1.5105932]
# fwd noisy =  [5.58232329]
# turn noisy =  [8.0368209]
# fwd noisy =  [5.00403558]
# turn noisy =  [-9.30697778]
# fwd noisy =  [5.39862764]
# turn noisy =  [5.27621638]
# fwd noisy =  [4.64573776]
# turn noisy =  [3.319864]
# fwd noisy =  [5.17696447]
# turn noisy =  [-1.05913323]
# fwd noisy =  [4.58774138]
# turn noisy =  [2.83705759]
# fwd noisy =  [4.53029637]
# turn noisy =  [-4.16301914]
# fwd noisy =  [5.71917627]
# turn noisy =  [5.07111533]
# fwd noisy =  [5.06263538]
# turn noisy =  [-1.66366531]
# fwd noisy =  [5.41973978]
# turn noisy =  [-0.4113982]
# fwd noisy =  [4.07654901]
# turn noisy =  [-5.23147465]
# fwd noisy =  [5.07161093]
# turn noisy =  [5.63931699]
# fwd noisy =  [5.3902921]
# turn noisy =  [-3.63912502]
# fwd noisy =  [5.4154628]
# turn noisy =  [-3.123422]
# fwd noisy =  [4.83283931]
# turn noisy =  [0.42347274]
# fwd noisy =  [4.56653127]
# turn noisy =  [-8.6316099]
# fwd noisy =  [4.86611215]
# turn noisy =  [6.79751376]
# fwd noisy =  [5.64094878]
# turn noisy =  [3.15403244]
# fwd noisy =  [5.30596591]
# turn noisy =  [3.46645585]
# fwd noisy =  [4.5282403]
# turn noisy =  [-1.69600333]
# fwd noisy =  [5.44986246]
# turn noisy =  [-5.56406196]
# fwd noisy =  [4.3435821]
# turn noisy =  [1.54760695]
# fwd noisy =  [0.32363558]
# turn noisy =  [33.7712596]
# fwd noisy =  [4.37797221]
# turn noisy =  [1.17005456]
# fwd noisy =  [5.78199146]
# turn noisy =  [6.91664206]
# fwd noisy =  [4.62661589]
# turn noisy =  [-0.76064739]
# fwd noisy =  [4.84377264]
# turn noisy =  [4.33625094]
# fwd noisy =  [4.52062622]
# turn noisy =  [-6.8570113]
# fwd noisy =  [5.31741264]
# turn noisy =  [2.74031468]
# fwd noisy =  [5.37711269]
# turn noisy =  [-4.00013093]
# fwd noisy =  [4.73309474]
# turn noisy =  [5.40315237]
# fwd noisy =  [4.21716112]
# turn noisy =  [7.73561018]
# fwd noisy =  [4.92738]
# turn noisy =  [2.15221322]
# fwd noisy =  [4.74390849]
# turn noisy =  [1.81633271]
# fwd noisy =  [0.29117289]
# turn noisy =  [27.9858691]
# fwd noisy =  [-0.12870732]
# turn noisy =  [30.40264824]
# fwd noisy =  [-0.10407548]
# turn noisy =  [24.24410474]
# fwd noisy =  [5.19487704]
# turn noisy =  [4.9361645]
# fwd noisy =  [5.23389469]
# turn noisy =  [-3.14206428]
# fwd noisy =  [3.3594053]
# turn noisy =  [-5.2901836]
# fwd noisy =  [4.91467068]
# turn noisy =  [6.66347866]
# fwd noisy =  [5.09907674]
# turn noisy =  [-3.81032981]
# fwd noisy =  [4.34623475]
# turn noisy =  [2.56122163]
# fwd noisy =  [5.34302857]
# turn noisy =  [-1.46216731]
# fwd noisy =  [5.00513502]
# turn noisy =  [-4.84786347]
# fwd noisy =  [5.69352021]
# turn noisy =  [-4.85041322]
# fwd noisy =  [4.79585499]
# turn noisy =  [5.4808992]
# fwd noisy =  [4.91060766]
# turn noisy =  [0.30951543]
# fwd noisy =  [5.73569556]
# turn noisy =  [-3.86195072]
# fwd noisy =  [4.39745665]
# turn noisy =  [1.36885616]
# fwd noisy =  [5.67412323]
# turn noisy =  [-2.71935846]
# fwd noisy =  [5.29223852]
# turn noisy =  [-5.81066034]
# fwd noisy =  [5.04300696]
# turn noisy =  [1.98925258]
# fwd noisy =  [5.22785997]
# turn noisy =  [3.8836949]
# fwd noisy =  [5.07461272]
# turn noisy =  [-5.52245743]
# fwd noisy =  [4.03065821]
# turn noisy =  [2.26536957]
# fwd noisy =  [4.61421046]
# turn noisy =  [1.25227404]
# fwd noisy =  [5.3165988]
# turn noisy =  [-5.68397884]
# fwd noisy =  [5.08573157]
# turn noisy =  [4.06430038]
# fwd noisy =  [4.31743296]
# turn noisy =  [-4.01041742]
# fwd noisy =  [5.45367527]
# turn noisy =  [-1.67559048]
# fwd noisy =  [4.12003364]
# turn noisy =  [8.57736015]
# fwd noisy =  [-0.23450791]
# turn noisy =  [27.06697117]
# fwd noisy =  [-0.35679406]
# turn noisy =  [31.43833315]
# fwd noisy =  [5.01753029]
# turn noisy =  [1.25814737]
# fwd noisy =  [4.93237957]
# turn noisy =  [-2.76407174]
# fwd noisy =  [5.65391066]
# turn noisy =  [5.83883612]
# fwd noisy =  [4.56025636]
# turn noisy =  [7.45911594]
# fwd noisy =  [4.50836869]
# turn noisy =  [-2.20581861]
# fwd noisy =  [5.09743243]
# turn noisy =  [-1.1996135]
# fwd noisy =  [5.43869559]
# turn noisy =  [-2.9267503]
# fwd noisy =  [4.9928296]
# turn noisy =  [0.82436268]
# fwd noisy =  [5.25321789]
# turn noisy =  [4.13339202]
# fwd noisy =  [5.20459232]
# turn noisy =  [-2.06430128]
# fwd noisy =  [5.23995402]
# turn noisy =  [4.17953985]
# fwd noisy =  [5.29003885]
# turn noisy =  [-5.96939284]
# fwd noisy =  [5.25618394]
# turn noisy =  [2.91412376]
# fwd noisy =  [0.23150964]
# turn noisy =  [-29.42177668]
# fwd noisy =  [-0.91984687]
# turn noisy =  [-22.94228547]
# fwd noisy =  [-0.037149]
# turn noisy =  [-23.95065588]
# fwd noisy =  [4.67973602]
# turn noisy =  [-1.63263281]
# fwd noisy =  [5.65386617]
# turn noisy =  [0.0554048]
# fwd noisy =  [3.86194012]
# turn noisy =  [-7.31852217]
# fwd noisy =  [4.872676]
# turn noisy =  [-8.50658758]
# fwd noisy =  [4.87117574]
# turn noisy =  [-4.93253354]
# fwd noisy =  [5.01475913]
# turn noisy =  [-3.28928718]
# fwd noisy =  [5.53494165]
# turn noisy =  [1.70900414]
# fwd noisy =  [5.41777895]
# turn noisy =  [-5.13100795]
# fwd noisy =  [4.99057331]
# turn noisy =  [-3.46372148]
# fwd noisy =  [5.43716213]
# turn noisy =  [1.99468938]
# fwd noisy =  [4.58314565]
# turn noisy =  [1.35795116]
# fwd noisy =  [0.74885904]
# turn noisy =  [-26.3585411]
# fwd noisy =  [-0.81691945]
# turn noisy =  [-32.85051973]
# fwd noisy =  [-0.6366488]
# turn noisy =  [-22.40872876]
# fwd noisy =  [3.95573386]
# turn noisy =  [-5.15939228]
# fwd noisy =  [3.68456871]
# turn noisy =  [-1.11704016]
# fwd noisy =  [4.92597392]
# turn noisy =  [5.55235148]
# fwd noisy =  [4.82572666]
# turn noisy =  [3.53386095]
# fwd noisy =  [4.56072971]
# turn noisy =  [-3.62167214]
# fwd noisy =  [4.64454829]
# turn noisy =  [-4.63908931]
# fwd noisy =  [4.25554937]
# turn noisy =  [1.44340762]
# fwd noisy =  [5.13052523]
# turn noisy =  [0.67166835]
# fwd noisy =  [5.58174108]
# turn noisy =  [1.27169391]
# fwd noisy =  [4.44730063]
# turn noisy =  [-10.3130581]
# fwd noisy =  [4.52090385]
# turn noisy =  [-2.8157263]
# fwd noisy =  [5.05727618]
# turn noisy =  [-2.83860078]
# fwd noisy =  [4.30794465]
# turn noisy =  [4.76326043]
# fwd noisy =  [4.38486597]
# turn noisy =  [3.78065076]
# fwd noisy =  [4.78221688]
# turn noisy =  [-1.25105434]
# fwd noisy =  [4.77381084]
# turn noisy =  [-0.05684973]
# fwd noisy =  [4.13941668]
# turn noisy =  [-3.31672109]
# fwd noisy =  [4.98968016]
# turn noisy =  [-11.31663031]
# fwd noisy =  [5.72820216]
# turn noisy =  [9.6909307]
# fwd noisy =  [5.07027705]
# turn noisy =  [-7.32886056]
# fwd noisy =  [5.35508731]
# turn noisy =  [-0.92904984]
# fwd noisy =  [5.88198399]
# turn noisy =  [1.4071163]
# fwd noisy =  [4.00330254]
# turn noisy =  [9.02689479]
# fwd noisy =  [4.78478365]
# turn noisy =  [5.47316088]
# fwd noisy =  [4.7361501]
# turn noisy =  [-5.30444624]
# fwd noisy =  [6.44206674]
# turn noisy =  [0.86280024]
# fwd noisy =  [5.05366844]
# turn noisy =  [-9.90301305]
# fwd noisy =  [5.08183023]
# turn noisy =  [2.22379574]
# fwd noisy =  [5.72362817]
# turn noisy =  [-0.30384634]
# fwd noisy =  [5.40653508]
# turn noisy =  [8.09106475]
# fwd noisy =  [4.71151393]
# turn noisy =  [-0.19788535]
# fwd noisy =  [6.04463039]
# turn noisy =  [-0.28038966]
# fwd noisy =  [5.21719958]
# turn noisy =  [3.63753195]
# fwd noisy =  [5.24091432]
# turn noisy =  [-1.22178279]
# fwd noisy =  [4.12958083]
# turn noisy =  [9.46626248]
# fwd noisy =  [0.69698015]
# turn noisy =  [-23.57223416]
# fwd noisy =  [0.22635458]
# turn noisy =  [-21.25954097]
# fwd noisy =  [-0.20333312]
# turn noisy =  [-30.51103077]
# fwd noisy =  [4.75542175]
# turn noisy =  [4.90062661]
# fwd noisy =  [5.57103368]
# turn noisy =  [-3.04987298]
# fwd noisy =  [5.60030885]
# turn noisy =  [7.67551059]
# fwd noisy =  [4.31348065]
# turn noisy =  [-4.25875702]
# fwd noisy =  [5.28575435]
# turn noisy =  [0.42921277]
# fwd noisy =  [4.62371412]
# turn noisy =  [-4.162544]
# fwd noisy =  [5.92644391]
# turn noisy =  [0.78598597]
# fwd noisy =  [5.06217406]
# turn noisy =  [-7.21487133]
# fwd noisy =  [4.36423127]
# turn noisy =  [3.65888691]
# fwd noisy =  [4.6614173]
# turn noisy =  [7.38079268]
# fwd noisy =  [4.57660518]
# turn noisy =  [0.20653009]
# fwd noisy =  [5.05332573]
# turn noisy =  [-0.80252379]
# fwd noisy =  [5.11845764]
# turn noisy =  [-10.21107785]
# fwd noisy =  [5.17646976]
# turn noisy =  [-4.77382902]
# fwd noisy =  [-0.47520801]
# turn noisy =  [-19.94099882]
